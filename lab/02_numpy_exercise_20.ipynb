# %% [markdown]
# # NumPy 연습문제 (기초 ~ 중급)
#
# 다음 문제들은 NumPy `ndarray`의 **rank(차원) 개념**, **배열 생성/변환**, **인덱싱**, **슬라이싱**, **shape 조작** 등을 체계적으로 익히도록 구성되어 있습니다.
#
# 각 문제 아래에 직접 코드를 작성해 보시기 바랍니다.

# %% [markdown]
# **문제 1.** 파이썬 리스트 `[1, 2, 3, 4, 5]`를 NumPy 1차원 배열로 변환하고 `ndim`과 `shape`을 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 2.** 0부터 9까지의 정수를 갖는 1차원 배열을 `np.arange`로 생성하고 처음 3개 원소와 마지막 2개 원소를 각각 슬라이싱하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 3.** (3, 4) shape을 갖는 2차원 배열을 `np.arange`로 생성하여 행렬 형태로 reshape하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 4.** 문제 3에서 생성한 배열에서 두 번째 행 전체를 슬라이싱으로 추출하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 5.** 문제 3 배열에서 첫 번째 열과 세 번째 열만 추출하는 슬라이싱 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 6.** (3, 3) 단위행렬을 생성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 7.** 모든 원소가 7인 (4, 2) 배열을 생성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 8.** 0~1 사이 난수를 포함하는 (2, 5) 배열을 생성하고 rank와 shape을 확인하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 9.** 2차원 배열에서 특정 원소 `arr[1, 2]`를 추출하는 코드와, 해당 원소의 dtype을 출력하는 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 10.** 1차원 배열을 (5, 1)과 (1, 5) 형태로 각각 reshape하는 코드를 작성하고 reshape 전후의 shape 변화를 비교하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 11.** (4, 4) 배열을 생성하고, 두 번째 행과 세 번째 열이 교차하는 원소를 인덱싱으로 추출하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 12.** (6, 6) 배열에서 2행~4행, 1열~3열 범위의 부분 배열을 슬라이싱으로 추출하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 13.** 3차원 배열 (2, 3, 4)를 생성하고, 특정 depth의 전체 행렬을 추출하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 14.** 3차원 배열에서 특정 depth의 특정 행만 추출하는 슬라이싱 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 15.** `np.concatenate`를 사용하여 두 개의 1차원 배열 `[1,2,3]`과 `[4,5,6]`을 연결하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 16.** (2, 3) 배열 두 개를 0축 기준, 1축 기준으로 각각 concatenate하는 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 17.** Boolean indexing을 사용하여 0~9 배열에서 짝수만 추출하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 18.** (5, 5) 배열에서 대각선에 위치한 값만 추출하는 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 19.** 배열을 전치(transpose)하는 예제를 작성하고, 전치 전후의 shape을 비교하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# **문제 20.** `np.newaxis` 또는 `None`을 이용해 1차원 배열을 (N, 1), (1, N) 형태로 변환하는 코드를 작성하시오.

# %%
# 여기에 코드를 작성하세요
